# %% [markdown]
# <a href="https://colab.research.google.com/github/hwanython/SaltLux-machin-learning/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # 0. 판다스를 이용하여 데이터 준비하기

# %% [markdown]
# 사용할 데이터
#
# 레모네이드: https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/lemonade.csv
#
# 보스턴: https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/boston.csv
#
# 아이리스: https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/iris.csv

# %%
import pandas as pd

파일경로 = 'https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)
레모네이드
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48
# 5  25   50

# %%
import pandas as pd

파일경로 = 'https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
보스턴
# Out:
#         crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
import pandas as pd

파일경로 = 'https://raw.githubusercontent.com/blackdew/ml-tensorflow/master/data/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)
아이리스
# Out:
#      꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭         품종
# 0     5.1  3.5    1.4   0.2     setosa
# 1     4.9  3.0    1.4   0.2     setosa
# 2     4.7  3.2    1.3   0.2     setosa
# 3     4.6  3.1    1.5   0.2     setosa
# 4     5.0  3.6    1.4   0.2     setosa
# ..    ...  ...    ...   ...        ...
# 145   6.7  3.0    5.2   2.3  virginica
# 146   6.3  2.5    5.0   1.9  virginica
# 147   6.5  3.0    5.2   2.0  virginica
# 148   6.2  3.4    5.4   2.3  virginica
# 149   5.9  3.0    5.1   1.8  virginica
#
# [150 rows x 5 columns]

# %%
독립 = 레모네이드[['온도']]
독립
# Out:
#    온도
# 0  20
# 1  21
# 2  22
# 3  23
# 4  24
# 5  25

# %%
종속 = 레모네이드[['판매량']]
종속
# Out:
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50

# %%
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
독립
# Out:
#         crim    zn  indus  chas    nox  ...  rad  tax  ptratio       b  lstat
# 0    0.00632  18.0   2.31     0  0.538  ...    1  296     15.3  396.90   4.98
# 1    0.02731   0.0   7.07     0  0.469  ...    2  242     17.8  396.90   9.14
# 2    0.02729   0.0   7.07     0  0.469  ...    2  242     17.8  392.83   4.03
# 3    0.03237   0.0   2.18     0  0.458  ...    3  222     18.7  394.63   2.94
# 4    0.06905   0.0   2.18     0  0.458  ...    3  222     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...  ...      ...     ...    ...
# 501  0.06263   0.0  11.93     0  0.573  ...    1  273     21.0  391.99   9.67
# 502  0.04527   0.0  11.93     0  0.573  ...    1  273     21.0  396.90   9.08
# 503  0.06076   0.0  11.93     0  0.573  ...    1  273     21.0  396.90   5.64
# 504  0.10959   0.0  11.93     0  0.573  ...    1  273     21.0  393.45   6.48
# 505  0.04741   0.0  11.93     0  0.573  ...    1  273     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
종속 = 보스턴[['medv']]
종속
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
보스턴.describe()
# Out:
#              crim          zn       indus  ...           b       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
type(보스턴.columns[1:4])
# Out:
# pandas.core.indexes.base.Index
